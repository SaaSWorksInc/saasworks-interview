# %% [markdown]
# <a href="https://colab.research.google.com/github/SaaSWorksInc/saasworks-interview/blob/master/Analyst_interview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import datetime
import numpy as np

# %%
from pathlib import Path
Path('my_data.db').touch()
import sqlite3
con = sqlite3.connect('my_data.db')
cur = con.cursor()
sqlite3.sqlite_version
# Out:
# '3.37.2'

# %% [markdown]
# ![Screenshot 2024-03-19 at 6.22.26 PM.png](data:image/png;base64,...)

# %% [markdown]
# Please go to this [Kaggle page](https://www.kaggle.com/datasets/chaitanyasood1/tmdb-5000-movies) and download the netflix_movies.csv file. Once downloaded, please drag it from your downloads folder over to the Files section on the left-hand side of your screen so it appears like the screenshot before running the below blocks of code.

# %%
t12 = pd.read_csv("/content//tmdb_5000_movies.csv", index_col=0, parse_dates=True)

# %%
t12.reset_index(inplace=True)

# %%
t12.to_sql('t12', con,  index=False)
# Out:
# 4803

# %% [markdown]
# Below is a test query on the data loaded above. Please make sure that it runs before we start the test.

# %%
pd.read_sql_query("""
SELECT
*
FROM
t12
LIMIT 10
""", con)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %% [markdown]
# Use the above block of code to edit the SQL query and answer the following questions:
#
# 1. What are the 5 longest movies in the dataset?
# 2. How many movies in total are in the dataset?
# 3. What was the average runtime for a movie in the dataset?
# 4. Create a table that shows the average duration for movies by year. Is there an identifiable trend you can spot?
# 5. Which Genre had the most movies produced over the time period?

# %%
pd.read_sql_query("""
SELECT
*
FROM
t12
order by runtime desc
LIMIT 5
""", con)
# Out:
#      budget                                             genres homepage  \
# 0  18000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...     None
# 1         0                      [{"id": 18, "name": "Drama"}]     None
# 2         0  [{"id": 10752, "name": "War"}, {"id": 18, "nam...     None
# 3  31115000  [{"id": 18, "name": "Drama"}, {"id": 36, "name...     None
# 4         0                      [{"id": 18, "name": "Drama"}]     None
#
#        id                                           keywords  \
# 0   43434  [{"id": 1419, "name": "gun"}, {"id": 7336, "na...
# 1  112430              [{"id": 11162, "name": "miniseries"}]
# 2   10655  [{"id": 393, "name": "civil war"}, {"id": 4097...
# 3    8095  [{"id": 5049, "name": "ancient rome"}, {"id": ...
# 4   10549  [{"id": 456, "name": "mother"}, {"id": 497, "n...
#
#   original_language original_title  \
# 0                en         Carlos
# 1                en    The Company
# 2                en     Gettysburg
# ...

# %% [markdown]
# How many movies in total are in the dataset?

# %%
pd.read_sql_query("""
SELECT
count(distinct id)
FROM
t12

""", con)
# Out:
#    count(distinct id)
# 0                4803

# %% [markdown]
# What was the average runtime for a movie in the dataset?

# %%
pd.read_sql_query("""
SELECT
avg(runtime)
FROM
t12

""", con)
# Out:
#    avg(runtime)
# 0    106.875859

# %% [markdown]
# Create a table that shows the average duration for movies by year. Is there an identifiable trend you can spot?

# %%
pd.read_sql_query("""
SELECT
STRFTIME('%Y', release_date) as year, avg(runtime)
FROM
t12
group by year
""", con)
# Out:
#     year  avg(runtime)
# 0   None      0.000000
# 1   1916    197.000000
# 2   1925    151.000000
# 3   1927    153.000000
# 4   1929    104.500000
# ..   ...           ...
# 86  2013    105.268398
# 87  2014    102.113445
# 88  2015    103.144860
# 89  2016    107.625000
# 90  2017    102.000000
#
# [91 rows x 2 columns]

# %% [markdown]
# Which Genre had the most movies produced over the time period?

# %%
pd.read_sql_query("""
SELECT
count(json_array_elemnt(genres->> '$.name'))) as cnt_movies, id

FROM
t12
group by id
""", con)
#[{"id": 80, "name": "Crime"},json_each(json_extract(features.data, '$.A.B.coordinates'))
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2017         try:
# -> 2018             cur.execute(*args, **kwargs)
#    2019             return cur
#
# OperationalError: no such function: json_each
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-22-2e9738c8c63a> in <cell line: 1>()
# ----> 1 pd.read_sql_query("""
#       2 SELECT
#       3 json_each(json_extract(genres, '$.name'))
#       4
#       5 FROM
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     395     """
#     396     pandas_sql = pandasSQL_builder(con)
# ...
